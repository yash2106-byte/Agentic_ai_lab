# %% [markdown]
# # Prompt Engineering

# %%
We can brodly describe say that writing good prompts are based on 2 principles
1. Write clear and specify instructions
2. Choose the optimal model based on your requirement
3. Definig negative edge case is more improntent than defineing posivitive edge case

# %%
We should use these tatics with the above mentined principals to get a desired output
1. use delimiters every place you get
2. ask for a structured output
3. check whether coditions are satisfied also check for the assumptions which are required to do a task
4. give an example succesfull of completing task
5. specify the steps to complete a task
