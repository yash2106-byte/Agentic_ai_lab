# %% [markdown]
# # Creating a basic image processing agent which will process an image in different ways

# %%
from dotenv import load_dotenv
import os
from groq import Groq

load_dotenv()
client = Groq(api_key=os.getenv("API_KEY"))

# %%
completion = client.chat.completions.create(
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "What's in this image?"
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://imgs.search.brave.com/5sa_7ONUZiCVUdjeQO7WkvaSy3RWsIdrDfcJmZ44gWA/rs:fit:500:0:1:0/g:ce/aHR0cHM6Ly9tZWRp/YS5nZXR0eWltYWdl/cy5jb20vaWQvMjE3/NzE3NDQ5Ny9waG90/by9sZXR0ZXItcy1w/YWludGVkLWluLWdv/bGQtYW5kLXdoaXRl/LW9uLWEtYmxhY2st/YmFja2dyb3VuZC1h/bmQtcGhvdG9ncmFw/aGVkLW9uLXRoZS1m/YWNhZGUtb2YtYS5q/cGc_cz02MTJ4NjEy/Jnc9MCZrPTIwJmM9/ZVRkd25uN1phNFJz/QXliSzBUcVV4bUpW/LUZUQ21ZMHBnNHVF/ZU9wV1hzVT0"
                    }
                }
            ]
        }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=False,
    stop=None,
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='The image depicts a large, gold-colored letter "S" with a white outline against a black background. The letter is centered in the frame and takes up most of the space.\n\n*   The letter "S" is the main focus of the image.\n    *   It is painted in gold color.\n    *   It has a white outline around it.\n    *   The letter appears to be hand-painted, as there are some imperfections and unevenness in the paint.\n*   The background of the image is solid black.\n    *   It provides a stark contrast to the gold and white colors of the letter.\n    *   The black background helps to make the letter stand out.\n\nOverall, the image is simple yet striking, with the bold gold letter "S" standing out against the dark background.', role='assistant', annotations=None, executed_tools=None, function_call=None, reasoning=None, tool_calls=None)

# %%
image_url = "https://imgs.search.brave.com/CO9uHpwmi5-zYp3Cdrrx1lr5JQU9BnKix0VHfdTnNXY/rs:fit:860:0:0:0/g:ce/aHR0cHM6Ly90My5m/dGNkbi5uZXQvanBn/LzE4LzgwLzU2Lzgw/LzM2MF9GXzE4ODA1/NjgwMDVfUWltVHQ5/Smk5eWJvdzZpSmtW/ZWpMNWpXRGIyaDdz/eWMuanBn"

if image_url:
    completion = client.chat.completions.create(
        model="meta-llama/llama-4-scout-17b-16e-instruct",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": "List what you observe in this photo in JSON format."
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": image_url
                        }
                    }
                ]
            },
            {
            "role": "user",
            "content": "Tell me more about the area."
            }
        ],
        temperature=1,
        max_completion_tokens=1024,
        top_p=1,
        stream=False,
        response_format={"type": "json_object"},
    )

    print(completion.choices[0].message.content)

else:
    print("No image URL provided.")
# Out:
# {
# "environment": {
#     "background": "dark",
#     "color": "black",
#     "lighting": "electric blue glow",
#     "surface": "flat"
#   },
#   "features": {
#     "lightning": {
#       "present": true,
#       "intensity": "high",
#       "color": "electric blue",
#       "shape": "branching"
#     },
#     "letter": {
#       "shape": "S",
#       "size": "large",
#       "material": "glowing"
#     }
#   },
#   "atmosphere": {
#     "mood": "dramatic",
#     "energy": "high"
#   }
# }

# %%
! git add .
! git commit -m"added image_processing"
! git push -u origin main
# Out:
# ...
# [main bc1f695] added image_processing
#  2 files changed, 218 insertions(+), 3 deletions(-)
#  create mode 100644 Basic operations/Image_Processing.ipynb
# branch 'main' set up to track 'origin/main'.
# To https://github.com/yash2106-byte/Agentic_ai_lab.git
#    026b6e3..bc1f695  main -> main
